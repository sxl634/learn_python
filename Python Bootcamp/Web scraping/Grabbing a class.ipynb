# %%
import requests
import bs4

# %%
result = requests.get("https://en.wikipedia.org/wiki/Ken_Thompson")

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Ken Thompson - Wikipedia</title>
# ...

# %%
soup.select(".toctext")[0]
# Out:
# <span class="toctext">Early life and education</span>

# %%
for item in soup.select(".toctext"):
    print(item.text)
# Out:
# Early life and education
# Career and research
# 1970s
# 1980s
# 1990s
# 2000s
# Awards
# National Academies
# Turing Award
# IEEE Richard W. Hamming Medal
# Fellow of the Computer History Museum
# National Medal of Technology
# Tsutomu Kanai Award
# Japan Prize
# Personal life
# References
# External links
