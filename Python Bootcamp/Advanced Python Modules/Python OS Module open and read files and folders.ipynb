# %%
pwd
# Out:
# 'C:\\Users\\slong\\OneDrive\\Desktop\\Python\\Python Bootcamp\\Advanced Python Modules'

# %%
f = open("practice.txt","w+")
f.write("This is a test string")
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\slong\\OneDrive\\Desktop\\Python\\Python Bootcamp\\Advanced Python Modules'

# %%
os.listdir("C:\\Users")
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'Public', 'slong']

# %%
import shutil

# %%
shutil.move("practice.txt","C:\\Users\\slong\\OneDrive\\Desktop\\Python\\Python Bootcamp")
# Out:
# 'C:\\Users\\slong\\OneDrive\\Desktop\\Python\\Python Bootcamp\\practice.txt'

# %%
os.listdir("C:\\Users\\slong\\OneDrive\\Desktop\\Python\\Python Bootcamp")
# Out:
# ['.ipynb_checkpoints',
#  'Advanced Python Modules',
#  'Decorators',
#  'Errors and exception handling',
#  'functions and methods',
#  'Generators',
#  'if else and loops',
#  'intro',
#  'Milestone project 1',
#  'Milestone Project 2',
#  'Modules and Packages',
#  'object and data structure basics',
#  'OOP',
#  'practice.txt']

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Collections.ipynb',
#  'Python OS Module open and read files and folders.ipynb']

# %%
shutil.move("C:\\Users\\slong\\OneDrive\\Desktop\\Python\\Python Bootcamp\\practice.txt", os.getcwd())
# Out:
# 'C:\\Users\\slong\\OneDrive\\Desktop\\Python\\Python Bootcamp\\Advanced Python Modules\\practice.txt'

# %%
send2trash.send2trash("practice.txt")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Collections.ipynb',
#  'Python OS Module open and read files and folders.ipynb']

# %%
for folder, sub_folders, files in os.walk("C:\\Users\\slong\\OneDrive\\Desktop\\Python"):
    print(f"Currently looking at {folder}")
    print("\n")
    print("The subfolders are: ")
    for sub_fold in sub_folders:
        print(f"Subfolder: {sub_fold}")
        
    print("\n")
    print("The files are: ")
    for f in files:
        print(f"File: {f}")
    print("\n")
# Out:
# Currently looking at C:\Users\slong\OneDrive\Desktop\Python
#
#
# The subfolders are:
# Subfolder: Learn Python
# Subfolder: Programming
# Subfolder: Python Bootcamp
# Subfolder: web_dev_test
#
#
# The files are:
#
#
# Currently looking at C:\Users\slong\OneDrive\Desktop\Python\Learn Python
#
#
# The subfolders are:
#
#
# The files are:
# File: helloworld.py
#
#
# Currently looking at C:\Users\slong\OneDrive\Desktop\Python\Programming
#
#
# The subfolders are:
# Subfolder: Python
#
#
# The files are:
#
#
# Currently looking at C:\Users\slong\OneDrive\Desktop\Python\Programming\Python
#
#
# The subfolders are:
# Subfolder: PythonBuildingBigApps-SourceCode
# Subfolder: __pycache__
#
#
# The files are:
# File: adding numbers and strings.py
# File: calculator.py
# File: calc_functions.py
# File: cat.py
# File: Character creation.py
# File: Conditionals.py
# File: guess my password.py
# File: main.py
# File: myCalculator5_start.py
# File: myEtchASketch.py
# File: myglossary.py
# ...
