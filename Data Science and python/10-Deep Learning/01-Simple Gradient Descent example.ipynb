# %% [markdown]
# # Simple Linear Regression. Minimal example

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # Creates 3D graphs

# %% [markdown]
# ## Generate random input data to train

# %%
observations = 1000

xs = np.random.uniform(low = -10, high=10, size=(observations,1))
zs = np.random.uniform(low = -10, high=10, size=(observations,1))

inputs = np.column_stack((xs,zs))

inputs.shape
# Out:
# (1000, 2)

# %% [markdown]
# ## Create the targets we will aim at

# %%
noise = np.random.uniform(-1,1,(observations,1))

targets = 2*xs - 3*zs + 5 + noise

print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ## Plot the training data

# %%
targets = targets.reshape(observations,)
fig = plt.figure()
ax = fig.add_subplot(111,projection="3d")
ax.plot(xs,zs,targets)
ax.set_xlabel("xs")
ax.set_ylabel("zs")
ax.set_zlabel("Targets")
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations,1)

# %% [markdown]
# ## Initialise variables

# %%
init_range = 0.1

weights = np.random.uniform(-init_range,init_range,size=(2,1))

biases = np.random.uniform(-init_range,init_range,size=1)

print(weights)
print(biases)
# Out:
# [[0.00740442]
#  [0.02729392]]
# [-0.00456402]

# %% [markdown]
# ## Set a learning rate

# %%
learning_rate = 0.01

# %% [markdown]
# ## Train the model

# %%
for i in range(10000):
    outputs = np.dot(inputs,weights) + biases
    deltas = outputs - targets
    
    loss = np.sum(deltas **2) / 2 / observations # Squaring ensures absolute values for loss, and /2 / observations means losses halved and then the mean of the halved losses calculated
    
    print(loss)
    
    deltas_scaled = deltas / observations
    
    weights = weights - learning_rate * np.dot(inputs.T, deltas_scaled)
    
    biases = biases - learning_rate * np.sum(deltas_scaled)
# Out:
# 227.54408178322203
# 109.7686230156451
# 56.34847190821576
# 32.042734221040334
# 20.912779563291725
# 15.74824400390125
# 13.286517755419068
# 12.050953472463592
# 11.373054827739649
# 10.950096058519946
# 10.644935815075353
# 10.395409033833035
# 10.173307180710372
# 9.965804069817077
# 9.767043559010697
# 9.574328827257032
# 9.38639579822643
# 9.20263070059855
# 9.022715412961261
# 8.846466672635964
# 8.67376315615523
# 8.504512396075944
# 8.338635760748042
# 8.176061625888927
# 8.016722262021524
# 7.86055240787771
# 7.707488609029202
# 7.55746890404133
# 7.41043266862049
# 7.266320531742809
# 7.125074324721077
# 6.986637045482294
# 6.8509528300026865
# 6.717966927238679
# 6.587625675886293
# 6.459876482206803
# 6.334667798567822
# 6.211949102535817
# 6.091670876441088
# 5.973784587374872
# 5.858242667595944
# 5.744998495332172
# 5.634006375966319
# 5.525221523597064
# 5.418600042967215
# 5.31409891175156
# 5.211675963197043
# 5.111289869108213
# 5.012900123171065
# ...

# %% [markdown]
# ## Print weights and biases

# %%
print(weights,biases)
# Out:
# [[ 1.99438605]
#  [-3.00240238]] [5.03967705]

# %% [markdown]
# ## Plot last outputs vs targets

# %% [markdown]
# Closer to the 45 degree line, the more accurate the model

# %%
plt.plot(outputs, targets)
plt.xlabel("outputs")
plt.ylabel("targets")
plt.show()
